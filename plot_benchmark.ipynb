# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
random_keys = pd.read_csv('random_keys.csv')
random_keys.plot()
plt.title("Random Keys")
plt.show()
random_keys
# Out:
#     NUM_ITEMS  COMP_COUNT  LEARNED_COMP_COUNT  CDF_ABS_ERROR  Unnamed: 4
# 0      411935     2059661             1267899        1403599         NaN
# 1      494238      988466              206049         481080         NaN
# 2      659096     5272731             2972535        2102340         NaN
# 3      164396      308138              105620         245853         NaN
# 4      245193      449726              105741         246590         NaN
# 5      242490      424135              105360         243793         NaN
# 6      989061     7912372             3985851        2749777         NaN
# 7      324571      600734              128526         382411         NaN
# 8      158366      301340               70548         163300         NaN
# 9      239486      414823               70626         165236         NaN
# 10    1400448    12603938             5514006        3343182         NaN
# 11     239276      431298               80727         190117         NaN
# ...

# %%
zipf_keys = pd.read_csv('zipf.csv')
zipf_keys.plot()
plt.title("Zipf Keys")
plt.show()
zipf_keys
# Out:
#     NUM_ITEMS  COMP_COUNT  LEARNED_COMP_COUNT  CDF_ABS_ERROR  Unnamed: 4
# 0      411935     2059651               46757        4437785         NaN
# 1      337455     1687241               62608        3781463         NaN
# 2      341175     1705795               66925        3767489         NaN
# 3      344309     1721503               70362        3622328         NaN
# 4      347165     1735690               71893        3759273         NaN
# 5      349794     1748941               72377        3828527         NaN
# 6      352281     1761278               72349        3957344         NaN
# 7      354657     1773176               74325        3800402         NaN
# 8      356956     1784660               74663        3732015         NaN
# 9      359127     1795348               74311        3607136         NaN
# 10     361191     1805903               74635        3778712         NaN
# 11     363165     1815694               74573        3866830         NaN
# ...
